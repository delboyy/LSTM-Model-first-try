# %%
# dataset @

# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060396
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062553
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063632
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062014
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060936
# ...          ...         ...         ...         ...         ...         ...
# 9476  2023-10-18  332.489990  335.589996  328.299988  330.109985  330.109985
# 9477  2023-10-19  332.149994  336.880005  330.910004  331.320007  331.320007
# 9478  2023-10-20  331.720001  331.920013  325.450012  326.670013  326.670013
# 9479  2023-10-23  325.470001  332.730011  324.390015  329.320007  329.320007
# 9480  2023-10-24  331.299988  331.839996  327.600006  330.529999  330.529999
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9476    23153600
# 9477    25052100
# 9478    25012600
# 9479    24374700
# 9480    30444300
#
# [9481 rows x 7 columns]

# %%
df = df[['Date', 'Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9476  2023-10-18  330.109985
# 9477  2023-10-19  331.320007
# 9478  2023-10-20  326.670013
# 9479  2023-10-23  329.320007
# 9480  2023-10-24  330.529999
#
# [9481 rows x 2 columns]

# %%
df['Date']
# Out:
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9476   2023-10-18
# 9477   2023-10-19
# 9478   2023-10-20
# 9479   2023-10-23
# 9480   2023-10-24
# Name: Date, Length: 9481, dtype: datetime64[ns]

# %%
import datetime
import pandas as pd

def str_to_datetime(date):
    if isinstance(date, str):  # Check if the input is a string
        split = date.split('-')
        year, month, day = int(split[0]), int(split[1]), int(split[2])
        return datetime.datetime(year=year, month=month, day=day)
    elif isinstance(date, pd.Timestamp):  # Check if the input is a Timestamp
        return date.to_pydatetime()  # Convert Timestamp to datetime object


datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#            Date       Close
# 0    1986-03-13    0.097222
# 1    1986-03-14    0.100694
# 2    1986-03-17    0.102431
# 3    1986-03-18    0.099826
# 4    1986-03-19    0.098090
# ...         ...         ...
# 9476 2023-10-18  330.109985
# 9477 2023-10-19  331.320007
# 9478 2023-10-20  326.670013
# 9479 2023-10-23  329.320007
# 9480 2023-10-24  330.529999
#
# [9481 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-50-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9476   2023-10-18
# 9477   2023-10-19
# 9478   2023-10-20
# 9479   2023-10-23
# 9480   2023-10-24
# Name: Date, Length: 9481, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-10-18  330.109985
# 2023-10-19  331.320007
# 2023-10-20  326.670013
# 2023-10-23  329.320007
# 2023-10-24  330.529999
#
# [9481 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 4s 103ms/step - loss: 84536.6250 - mean_absolute_error: 289.0092 - val_loss: 92194.4922 - val_mean_absolute_error: 303.5482
# Epoch 2/100
# 7/7 [==============================] - 0s 10ms/step - loss: 84172.4297 - mean_absolute_error: 288.3759 - val_loss: 91681.1016 - val_mean_absolute_error: 302.7013
# Epoch 3/100
# 7/7 [==============================] - 0s 10ms/step - loss: 83669.9688 - mean_absolute_error: 287.5039 - val_loss: 91115.9688 - val_mean_absolute_error: 301.7664
# Epoch 4/100
# 7/7 [==============================] - 0s 13ms/step - loss: 83063.2656 - mean_absolute_error: 286.4442 - val_loss: 90298.3984 - val_mean_absolute_error: 300.4087
# Epoch 5/100
# 7/7 [==============================] - 0s 13ms/step - loss: 82215.2266 - mean_absolute_error: 284.9614 - val_loss: 89363.7266 - val_mean_absolute_error: 298.8490
# Epoch 6/100
# 7/7 [==============================] - 0s 15ms/step - loss: 81267.0547 - mean_absolute_error: 283.3023 - val_loss: 88171.0781 - val_mean_absolute_error: 296.8469
# Epoch 7/100
# 7/7 [==============================] - 0s 13ms/step - loss: 79928.7891 - mean_absolute_error: 280.9233 - val_loss: 86386.0391 - val_mean_absolute_error: 293.8249
# Epoch 8/100
# 7/7 [==============================] - 0s 12ms/step - loss: 78165.6875 - mean_absolute_error: 277.7625 - val_loss: 84454.7578 - val_mean_absolute_error: 290.5197
# Epoch 9/100
# 7/7 [==============================] - 0s 11ms/step - loss: 76096.9141 - mean_absolute_error: 274.0061 - val_loss: 81749.9688 - val_mean_absolute_error: 285.8267
# Epoch 10/100
# 7/7 [==============================] - 0s 14ms/step - loss: 73289.6953 - mean_absolute_error: 268.8589 - val_loss: 78603.8516 - val_mean_absolute_error: 280.2693
# Epoch 11/100
# 7/7 [==============================] - 0s 14ms/step - loss: 70327.6875 - mean_absolute_error: 263.3004 - val_loss: 75344.4062 - val_mean_absolute_error: 274.3927
# Epoch 12/100
# 7/7 [==============================] - 0s 11ms/step - loss: 66891.5000 - mean_absolute_error: 256.6472 - val_loss: 71029.2031 - val_mean_absolute_error: 266.4133
# Epoch 13/100
# 7/7 [==============================] - 0s 15ms/step - loss: 62452.3984 - mean_absolute_error: 247.8395 - val_loss: 65817.3438 - val_mean_absolute_error: 256.4451
# Epoch 14/100
# 7/7 [==============================] - 0s 11ms/step - loss: 57282.5430 - mean_absolute_error: 237.2024 - val_loss: 60058.4805 - val_mean_absolute_error: 244.9598
# Epoch 15/100
# 7/7 [==============================] - 0s 12ms/step - loss: 51559.8242 - mean_absolute_error: 224.8258 - val_loss: 53307.7188 - val_mean_absolute_error: 230.7700
# Epoch 16/100
# 7/7 [==============================] - 0s 14ms/step - loss: 45359.2305 - mean_absolute_error: 210.6246 - val_loss: 46949.1484 - val_mean_absolute_error: 216.5553
# Epoch 17/100
# 7/7 [==============================] - 0s 11ms/step - loss: 39427.1719 - mean_absolute_error: 195.9593 - val_loss: 40487.8906 - val_mean_absolute_error: 201.0844
# Epoch 18/100
# 7/7 [==============================] - 0s 12ms/step - loss: 33421.5039 - mean_absolute_error: 180.0041 - val_loss: 34038.1211 - val_mean_absolute_error: 184.3505
# Epoch 19/100
# 7/7 [==============================] - 0s 14ms/step - loss: 27475.3125 - mean_absolute_error: 162.6203 - val_loss: 27577.7695 - val_mean_absolute_error: 165.9060
# Epoch 20/100
# 7/7 [==============================] - 0s 14ms/step - loss: 21753.4785 - mean_absolute_error: 143.9159 - val_loss: 21588.5977 - val_mean_absolute_error: 146.7493
# Epoch 21/100
# 7/7 [==============================] - 0s 10ms/step - loss: 16460.5430 - mean_absolute_error: 124.1997 - val_loss: 16146.5850 - val_mean_absolute_error: 126.8606
# Epoch 22/100
# 7/7 [==============================] - 0s 10ms/step - loss: 11970.0234 - mean_absolute_error: 104.6730 - val_loss: 11617.7227 - val_mean_absolute_error: 107.5396
# Epoch 23/100
# 7/7 [==============================] - 0s 10ms/step - loss: 8333.2119 - mean_absolute_error: 85.3261 - val_loss: 7750.7700 - val_mean_absolute_error: 87.7366
# Epoch 24/100
# 7/7 [==============================] - 0s 10ms/step - loss: 5326.2720 - mean_absolute_error: 65.5332 - val_loss: 4847.9287 - val_mean_absolute_error: 69.2458
# Epoch 25/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3377.9814 - mean_absolute_error: 48.6538 - val_loss: 2900.4568 - val_mean_absolute_error: 53.3616
# Epoch 26/100
# 7/7 [==============================] - 0s 10ms/step - loss: 2119.7502 - mean_absolute_error: 37.0096 - val_loss: 1504.2311 - val_mean_absolute_error: 38.0870
# Epoch 27/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1288.3235 - mean_absolute_error: 29.9935 - val_loss: 655.4197 - val_mean_absolute_error: 24.5453
# Epoch 28/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1037.4319 - mean_absolute_error: 27.2773 - val_loss: 428.3203 - val_mean_absolute_error: 19.4009
# Epoch 29/100
# 7/7 [==============================] - 0s 11ms/step - loss: 983.9402 - mean_absolute_error: 26.4516 - val_loss: 290.6298 - val_mean_absolute_error: 15.4700
# Epoch 30/100
# 7/7 [==============================] - 0s 10ms/step - loss: 986.1223 - mean_absolute_error: 26.5517 - val_loss: 310.4023 - val_mean_absolute_error: 16.0795
# Epoch 31/100
# 7/7 [==============================] - 0s 10ms/step - loss: 992.8174 - mean_absolute_error: 26.6546 - val_loss: 278.4521 - val_mean_absolute_error: 15.1081
# Epoch 32/100
# 7/7 [==============================] - 0s 13ms/step - loss: 976.5059 - mean_absolute_error: 26.3622 - val_loss: 163.5840 - val_mean_absolute_error: 11.0017
# Epoch 33/100
# 7/7 [==============================] - 0s 9ms/step - loss: 952.3824 - mean_absolute_error: 26.0686 - val_loss: 253.0508 - val_mean_absolute_error: 14.3337
# Epoch 34/100
# 7/7 [==============================] - 0s 9ms/step - loss: 922.1617 - mean_absolute_error: 25.6241 - val_loss: 174.4084 - val_mean_absolute_error: 11.4828
# Epoch 35/100
# 7/7 [==============================] - 0s 10ms/step - loss: 921.5312 - mean_absolute_error: 25.6637 - val_loss: 238.6531 - val_mean_absolute_error: 13.8788
# Epoch 36/100
# 7/7 [==============================] - 0s 10ms/step - loss: 908.6738 - mean_absolute_error: 25.4519 - val_loss: 232.9932 - val_mean_absolute_error: 13.7002
# Epoch 37/100
# 7/7 [==============================] - 0s 10ms/step - loss: 885.2781 - mean_absolute_error: 25.1247 - val_loss: 200.7945 - val_mean_absolute_error: 12.5583
# Epoch 38/100
# 7/7 [==============================] - 0s 13ms/step - loss: 872.3489 - mean_absolute_error: 24.9458 - val_loss: 236.8444 - val_mean_absolute_error: 13.8528
# Epoch 39/100
# 7/7 [==============================] - 0s 9ms/step - loss: 858.0784 - mean_absolute_error: 24.7102 - val_loss: 193.0559 - val_mean_absolute_error: 12.2940
# Epoch 40/100
# 7/7 [==============================] - 0s 9ms/step - loss: 850.1631 - mean_absolute_error: 24.6747 - val_loss: 170.3046 - val_mean_absolute_error: 11.3786
# Epoch 41/100
# 7/7 [==============================] - 0s 11ms/step - loss: 844.8188 - mean_absolute_error: 24.4794 - val_loss: 268.4237 - val_mean_absolute_error: 14.9071
# Epoch 42/100
# 7/7 [==============================] - 0s 14ms/step - loss: 822.2083 - mean_absolute_error: 24.1332 - val_loss: 189.4426 - val_mean_absolute_error: 12.2002
# Epoch 43/100
# 7/7 [==============================] - 0s 10ms/step - loss: 807.4412 - mean_absolute_error: 23.9854 - val_loss: 205.9767 - val_mean_absolute_error: 12.8335
# Epoch 44/100
# 7/7 [==============================] - 0s 10ms/step - loss: 783.1769 - mean_absolute_error: 23.6365 - val_loss: 182.7453 - val_mean_absolute_error: 11.9499
# Epoch 45/100
# 7/7 [==============================] - 0s 10ms/step - loss: 771.6492 - mean_absolute_error: 23.3961 - val_loss: 223.7124 - val_mean_absolute_error: 13.4885
# Epoch 46/100
# 7/7 [==============================] - 0s 10ms/step - loss: 749.6966 - mean_absolute_error: 23.1678 - val_loss: 214.5186 - val_mean_absolute_error: 13.1792
# Epoch 47/100
# 7/7 [==============================] - 0s 10ms/step - loss: 724.6234 - mean_absolute_error: 22.6615 - val_loss: 193.0225 - val_mean_absolute_error: 12.3868
# Epoch 48/100
# 7/7 [==============================] - 0s 11ms/step - loss: 690.9952 - mean_absolute_error: 22.0960 - val_loss: 203.2284 - val_mean_absolute_error: 12.8210
# Epoch 49/100
# 7/7 [==============================] - 0s 10ms/step - loss: 656.6140 - mean_absolute_error: 21.5349 - val_loss: 218.7356 - val_mean_absolute_error: 13.3959
# Epoch 50/100
# 7/7 [==============================] - 0s 10ms/step - loss: 612.6979 - mean_absolute_error: 20.7389 - val_loss: 178.7059 - val_mean_absolute_error: 11.9433
# Epoch 51/100
# 7/7 [==============================] - 0s 10ms/step - loss: 586.3408 - mean_absolute_error: 20.2927 - val_loss: 184.0747 - val_mean_absolute_error: 12.1876
# Epoch 52/100
# 7/7 [==============================] - 0s 10ms/step - loss: 552.6785 - mean_absolute_error: 19.7105 - val_loss: 92.4020 - val_mean_absolute_error: 7.9308
# Epoch 53/100
# 7/7 [==============================] - 0s 10ms/step - loss: 468.0604 - mean_absolute_error: 18.1879 - val_loss: 243.0410 - val_mean_absolute_error: 14.4565
# Epoch 54/100
# 7/7 [==============================] - 0s 14ms/step - loss: 468.5073 - mean_absolute_error: 18.2533 - val_loss: 141.4585 - val_mean_absolute_error: 10.4811
# Epoch 55/100
# 7/7 [==============================] - 0s 13ms/step - loss: 389.6403 - mean_absolute_error: 16.2609 - val_loss: 45.9548 - val_mean_absolute_error: 5.3331
# Epoch 56/100
# 7/7 [==============================] - 0s 11ms/step - loss: 337.3902 - mean_absolute_error: 15.1478 - val_loss: 47.9590 - val_mean_absolute_error: 5.4948
# Epoch 57/100
# 7/7 [==============================] - 0s 11ms/step - loss: 290.9486 - mean_absolute_error: 13.8204 - val_loss: 43.1476 - val_mean_absolute_error: 5.3262
# Epoch 58/100
# 7/7 [==============================] - 0s 13ms/step - loss: 270.0732 - mean_absolute_error: 13.7425 - val_loss: 47.8174 - val_mean_absolute_error: 5.5597
# Epoch 59/100
# 7/7 [==============================] - 0s 12ms/step - loss: 236.9516 - mean_absolute_error: 12.5278 - val_loss: 71.9303 - val_mean_absolute_error: 7.0102
# Epoch 60/100
# 7/7 [==============================] - 0s 12ms/step - loss: 206.9538 - mean_absolute_error: 11.5269 - val_loss: 37.2669 - val_mean_absolute_error: 5.2031
# Epoch 61/100
# 7/7 [==============================] - 0s 12ms/step - loss: 181.8712 - mean_absolute_error: 10.7246 - val_loss: 32.7157 - val_mean_absolute_error: 5.0222
# Epoch 62/100
# 7/7 [==============================] - 0s 14ms/step - loss: 177.4601 - mean_absolute_error: 10.6449 - val_loss: 35.2015 - val_mean_absolute_error: 4.9685
# Epoch 63/100
# 7/7 [==============================] - 0s 12ms/step - loss: 166.4994 - mean_absolute_error: 10.5016 - val_loss: 30.8223 - val_mean_absolute_error: 4.9047
# Epoch 64/100
# 7/7 [==============================] - 0s 14ms/step - loss: 128.5855 - mean_absolute_error: 8.9725 - val_loss: 30.0542 - val_mean_absolute_error: 4.8738
# Epoch 65/100
# 7/7 [==============================] - 0s 14ms/step - loss: 96.7883 - mean_absolute_error: 7.4205 - val_loss: 29.9822 - val_mean_absolute_error: 4.8508
# Epoch 66/100
# 7/7 [==============================] - 0s 16ms/step - loss: 76.1539 - mean_absolute_error: 6.5104 - val_loss: 30.5468 - val_mean_absolute_error: 4.8385
# Epoch 67/100
# 7/7 [==============================] - 0s 12ms/step - loss: 63.7894 - mean_absolute_error: 5.8069 - val_loss: 30.5686 - val_mean_absolute_error: 4.8175
# Epoch 68/100
# 7/7 [==============================] - 0s 14ms/step - loss: 54.1421 - mean_absolute_error: 5.4325 - val_loss: 33.1207 - val_mean_absolute_error: 4.8738
# Epoch 69/100
# 7/7 [==============================] - 0s 14ms/step - loss: 48.4496 - mean_absolute_error: 5.1964 - val_loss: 40.5467 - val_mean_absolute_error: 5.0652
# Epoch 70/100
# 7/7 [==============================] - 0s 15ms/step - loss: 42.2452 - mean_absolute_error: 4.8443 - val_loss: 33.0501 - val_mean_absolute_error: 4.8638
# Epoch 71/100
# 7/7 [==============================] - 0s 12ms/step - loss: 44.5648 - mean_absolute_error: 5.2878 - val_loss: 31.9129 - val_mean_absolute_error: 4.8129
# Epoch 72/100
# 7/7 [==============================] - 0s 12ms/step - loss: 37.5817 - mean_absolute_error: 4.9038 - val_loss: 41.3962 - val_mean_absolute_error: 5.1119
# Epoch 73/100
# 7/7 [==============================] - 0s 11ms/step - loss: 33.4634 - mean_absolute_error: 4.5374 - val_loss: 47.9219 - val_mean_absolute_error: 5.5143
# Epoch 74/100
# 7/7 [==============================] - 0s 11ms/step - loss: 34.7709 - mean_absolute_error: 4.7254 - val_loss: 79.7686 - val_mean_absolute_error: 7.2186
# Epoch 75/100
# 7/7 [==============================] - 0s 12ms/step - loss: 37.0901 - mean_absolute_error: 4.9092 - val_loss: 93.5766 - val_mean_absolute_error: 8.0024
# Epoch 76/100
# 7/7 [==============================] - 0s 12ms/step - loss: 34.1310 - mean_absolute_error: 4.6526 - val_loss: 48.2587 - val_mean_absolute_error: 5.5409
# Epoch 77/100
# 7/7 [==============================] - 0s 15ms/step - loss: 32.0272 - mean_absolute_error: 4.5479 - val_loss: 40.4099 - val_mean_absolute_error: 5.4396
# Epoch 78/100
# 7/7 [==============================] - 0s 12ms/step - loss: 37.2703 - mean_absolute_error: 5.0709 - val_loss: 34.7771 - val_mean_absolute_error: 4.8360
# Epoch 79/100
# 7/7 [==============================] - 0s 9ms/step - loss: 26.7533 - mean_absolute_error: 4.1934 - val_loss: 38.8863 - val_mean_absolute_error: 4.9983
# Epoch 80/100
# 7/7 [==============================] - 0s 11ms/step - loss: 25.6674 - mean_absolute_error: 4.0335 - val_loss: 45.5884 - val_mean_absolute_error: 5.3672
# Epoch 81/100
# 7/7 [==============================] - 0s 10ms/step - loss: 21.4468 - mean_absolute_error: 3.7507 - val_loss: 44.0156 - val_mean_absolute_error: 5.2707
# Epoch 82/100
# 7/7 [==============================] - 0s 10ms/step - loss: 22.8458 - mean_absolute_error: 3.8047 - val_loss: 57.0955 - val_mean_absolute_error: 5.9965
# Epoch 83/100
# 7/7 [==============================] - 0s 13ms/step - loss: 26.4481 - mean_absolute_error: 4.1812 - val_loss: 66.8615 - val_mean_absolute_error: 6.5528
# Epoch 84/100
# 7/7 [==============================] - 0s 10ms/step - loss: 38.0864 - mean_absolute_error: 4.9588 - val_loss: 90.3651 - val_mean_absolute_error: 7.8261
# Epoch 85/100
# 7/7 [==============================] - 0s 10ms/step - loss: 27.6329 - mean_absolute_error: 4.2144 - val_loss: 90.2839 - val_mean_absolute_error: 7.8296
# Epoch 86/100
# 7/7 [==============================] - 0s 15ms/step - loss: 23.1135 - mean_absolute_error: 3.9036 - val_loss: 75.5920 - val_mean_absolute_error: 7.0578
# Epoch 87/100
# 7/7 [==============================] - 0s 17ms/step - loss: 21.8413 - mean_absolute_error: 3.8378 - val_loss: 93.9770 - val_mean_absolute_error: 8.0139
# Epoch 88/100
# 7/7 [==============================] - 0s 18ms/step - loss: 24.4949 - mean_absolute_error: 3.9785 - val_loss: 79.0036 - val_mean_absolute_error: 7.2309
# Epoch 89/100
# 7/7 [==============================] - 0s 15ms/step - loss: 18.6298 - mean_absolute_error: 3.4739 - val_loss: 51.7590 - val_mean_absolute_error: 5.6788
# Epoch 90/100
# 7/7 [==============================] - 0s 14ms/step - loss: 18.4788 - mean_absolute_error: 3.4560 - val_loss: 60.0131 - val_mean_absolute_error: 6.1611
# Epoch 91/100
# 7/7 [==============================] - 0s 17ms/step - loss: 19.6896 - mean_absolute_error: 3.5633 - val_loss: 91.7807 - val_mean_absolute_error: 7.9132
# Epoch 92/100
# 7/7 [==============================] - 0s 18ms/step - loss: 20.7036 - mean_absolute_error: 3.6826 - val_loss: 50.3038 - val_mean_absolute_error: 5.5876
# Epoch 93/100
# 7/7 [==============================] - 0s 17ms/step - loss: 18.3617 - mean_absolute_error: 3.4045 - val_loss: 39.0186 - val_mean_absolute_error: 5.2521
# Epoch 94/100
# 7/7 [==============================] - 0s 14ms/step - loss: 23.9141 - mean_absolute_error: 3.8705 - val_loss: 37.5819 - val_mean_absolute_error: 4.8793
# Epoch 95/100
# 7/7 [==============================] - 0s 14ms/step - loss: 24.1344 - mean_absolute_error: 4.0323 - val_loss: 50.3605 - val_mean_absolute_error: 5.5728
# Epoch 96/100
# 7/7 [==============================] - 0s 16ms/step - loss: 23.5267 - mean_absolute_error: 4.0084 - val_loss: 66.3349 - val_mean_absolute_error: 6.5033
# Epoch 97/100
# 7/7 [==============================] - 0s 16ms/step - loss: 21.4793 - mean_absolute_error: 3.6840 - val_loss: 48.6041 - val_mean_absolute_error: 5.4478
# Epoch 98/100
# 7/7 [==============================] - 0s 16ms/step - loss: 17.3962 - mean_absolute_error: 3.3089 - val_loss: 46.2869 - val_mean_absolute_error: 5.3233
# Epoch 99/100
# 1/7 [===>..........................] - ETA: 0s - loss: 19.1042 - mean_absolute_error: 3.4254
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-4d1e0d2f4cad> in <cell line: 15>()
#      13               metrics=['mean_absolute_error'])
#      14
# ---> 15 model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1787                             logs = tmp_logs
#    1788                             end_step = step + data_handler.step_increment
# -> 1789                             callbacks.on_train_batch_end(end_step, logs)
#    1790                             if self.stop_training:
#    1791                                 break
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#     473         """
#     474         if self._should_call_train_batch_hooks:
# --> 475             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     476
#     477     def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     320             self._call_batch_begin_hook(mode, batch, logs)
#     321         elif hook == "end":
# --> 322             self._call_batch_end_hook(mode, batch, logs)
#     323         else:
#     324             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     343             self._batch_times.append(batch_time)
#     344
# --> 345         self._call_batch_hook_helper(hook_name, batch, logs)
#     346
#     347         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     391         for callback in self.callbacks:
#     392             hook = getattr(callback, hook_name)
# --> 393             hook(batch, logs)
#     394
#     395         if self._check_timing:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#    1091
#    1092     def on_train_batch_end(self, batch, logs=None):
# -> 1093         self._batch_update_progbar(batch, logs)
#    1094
#    1095     def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1153         """Updates the progbar."""
#    1154         logs = logs or {}
# -> 1155         self._maybe_init_progbar()
#    1156         if self.use_steps:
#    1157             self.seen = batch + 1  # One-indexed.
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _maybe_init_progbar(self)
#    1128             # first train step.
#    1129             self.stateful_metrics = self.stateful_metrics.union(
# -> 1130                 set(m.name for m in self.model.metrics)
#    1131             )
#    1132
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in metrics(self)
#     910         if self._is_compiled:
#     911             if self.compiled_loss is not None:
# --> 912                 metrics += self.compiled_loss.metrics
#     913             if self.compiled_metrics is not None:
#     914                 metrics += self.compiled_metrics.metrics
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/compile_utils.py in metrics(self)
#     181         per_output_metrics = [
#     182             metric_obj
# --> 183             for metric_obj in tf.nest.flatten(self._per_output_metrics)
#     184             if metric_obj is not None
#     185         ]
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest.py in flatten(structure, expand_composites)
#     292     TypeError: The nest is or contains a dict with non-sortable keys.
#     293   """
# --> 294   return nest_util.flatten(
#     295       nest_util.Modality.CORE, structure, expand_composites
#     296   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in flatten(modality, structure, expand_composites)
#     813   """
#     814   if modality == Modality.CORE:
# --> 815     return _tf_core_flatten(structure, expand_composites)
#     816   elif modality == Modality.DATA:
#     817     return _tf_data_flatten(structure)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in _tf_core_flatten(structure, expand_composites)
#     826   if structure is None:
#     827     return [None]
# --> 828   expand_composites = bool(expand_composites)
#     829   return _pywrap_utils.Flatten(structure, expand_composites)
#     830
#
# KeyboardInterrupt:

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend((('Training Prediction', 'Training observations')))
# Out:
# 7/7 [==============================] - 0s 5ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 30ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for traget_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_predicition = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_predicition)
  last_window[-1] = next_predicition
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
